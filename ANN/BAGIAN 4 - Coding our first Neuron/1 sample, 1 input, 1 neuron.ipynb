# %%
from IPython.display import display, Latex

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
luas_tanah = 100 # m^2
harga_rumah = 500 # juta rupiah

weight = 0.2
bias = 0.0

harga_prediksi = weight * luas_tanah + bias
print(harga_prediksi)
# Out:
# 20.0
