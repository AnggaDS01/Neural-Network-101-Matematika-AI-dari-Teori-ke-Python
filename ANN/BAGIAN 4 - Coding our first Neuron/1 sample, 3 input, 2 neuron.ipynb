# %%
from IPython.display import display, Math, Latex

# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %%
# LUAS TANAH m^2
x_11 = 100
x_21 = 150
x_31 = 175
x_41 = 200

# KAMAR TIDUR
x_12 = 3
x_22 = 5
x_32 = 5
x_42 = 6

# KAMAR MANDI
x_13 = 2
x_23 = 3
x_33 = 4
x_43 = 3

# HARGA RUMAH (juta rupiah)
y_1 = 500
y_2 = 850
y_3 = 900
y_4 = 1100

# WEIGHT PADA NEURON 1
w_11 = 0.1
w_21 = 0.2
w_31 = 0.3

# BIAS PADA NEURON 1
b_1 = 0.0

# WEIGHT PADA NEURON 2
w_12 = 0.4
w_22 = 0.5
w_32 = 0.6

# BIAS PADA NEURON 2
b_2 = 0.0


y_1_neuron_1 = w_11 * x_11 + w_21 * x_12 + w_31 * x_13 + b_1
y_2_neuron_1 = w_11 * x_21 + w_21 * x_22 + w_31 * x_23 + b_1
y_3_neuron_1 = w_11 * x_31 + w_21 * x_32 + w_31 * x_33 + b_1
y_4_neuron_1 = w_11 * x_41 + w_21 * x_42 + w_31 * x_43 + b_1

y_1_neuron_2 = w_12 * x_11 + w_22 * x_12 + w_32 * x_13 + b_2
y_2_neuron_2 = w_12 * x_21 + w_22 * x_22 + w_32 * x_23 + b_2
y_3_neuron_2 = w_12 * x_31 + w_22 * x_32 + w_32 * x_33 + b_2
y_4_neuron_2 = w_12 * x_41 + w_22 * x_42 + w_32 * x_43 + b_2

display(Latex(
    f"{' HIDDEN OUTPUT 1 '.center(40, '=')}\n\n"
	r'$y_{11}$' f'= {w_11} $\\times$ {x_11} + {w_21} $\\times$ {x_12} + {w_31} $\\times$ {x_13} + {b_1} = {y_1_neuron_1:.2f}\n\n'
	r'$y_{12}$' f'= {w_11} $\\times$ {x_21} + {w_21} $\\times$ {x_22} + {w_31} $\\times$ {x_23} + {b_1} = {y_2_neuron_1:.2f}\n\n'
	r'$y_{13}$' f'= {w_11} $\\times$ {x_31} + {w_21} $\\times$ {x_32} + {w_31} $\\times$ {x_33} + {b_1} = {y_3_neuron_1:.2f}\n\n'
	r'$y_{14}$' f'= {w_11} $\\times$ {x_41} + {w_21} $\\times$ {x_42} + {w_31} $\\times$ {x_43} + {b_1} = {y_4_neuron_1:.2f}\n\n'

    f"\{' HIDDEN OUTPUT 2 '.center(40, '=')}\n\n"
	r'$y_{21}$' f'= {w_12} $\\times$ {x_11} + {w_22} $\\times$ {x_12} + {w_32} $\\times$ {x_13} + {b_2} = {y_1_neuron_2:.2f}\n\n'
	r'$y_{22}$' f'= {w_12} $\\times$ {x_21} + {w_22} $\\times$ {x_22} + {w_32} $\\times$ {x_23} + {b_2} = {y_2_neuron_2:.2f}\n\n'
	r'$y_{23}$' f'= {w_12} $\\times$ {x_31} + {w_22} $\\times$ {x_32} + {w_32} $\\times$ {x_33} + {b_2} = {y_3_neuron_2:.2f}\n\n'
	r'$y_{24}$' f'= {w_12} $\\times$ {x_41} + {w_22} $\\times$ {x_42} + {w_32} $\\times$ {x_43} + {b_2} = {y_4_neuron_2:.2f}\n\n'
))
# Out:
# =========== HIDDEN OUTPUT 1 ============
#
# $y_{11}$= 0.1 $\times$ 100 + 0.2 $\times$ 3 + 0.3 $\times$ 2 + 0.0 = 11.20
#
# $y_{12}$= 0.1 $\times$ 150 + 0.2 $\times$ 5 + 0.3 $\times$ 3 + 0.0 = 16.90
#
# $y_{13}$= 0.1 $\times$ 175 + 0.2 $\times$ 5 + 0.3 $\times$ 4 + 0.0 = 19.70
#
# $y_{14}$= 0.1 $\times$ 200 + 0.2 $\times$ 6 + 0.3 $\times$ 3 + 0.0 = 22.10
#
# \=========== HIDDEN OUTPUT 2 ============
#
# $y_{21}$= 0.4 $\times$ 100 + 0.5 $\times$ 3 + 0.6 $\times$ 2 + 0.0 = 42.70
#
# $y_{22}$= 0.4 $\times$ 150 + 0.5 $\times$ 5 + 0.6 $\times$ 3 + 0.0 = 64.30
#
# $y_{23}$= 0.4 $\times$ 175 + 0.5 $\times$ 5 + 0.6 $\times$ 4 + 0.0 = 74.90
#
# $y_{24}$= 0.4 $\times$ 200 + 0.5 $\times$ 6 + 0.6 $\times$ 3 + 0.0 = 84.80
