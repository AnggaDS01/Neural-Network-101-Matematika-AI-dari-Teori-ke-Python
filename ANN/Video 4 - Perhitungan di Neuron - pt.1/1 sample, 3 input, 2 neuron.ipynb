# %%
from IPython.display import display, Latex

# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %%
def display_output():
    display(Latex(
    f'$y_1$ = {x_1} $\\times$ {w_11} + {x_2} $\\times$ {w_21} + {x_3} $\\times$ {w_31} + {b_1} = {y_1}\n\n'
	f'$y_2$ = {x_1} $\\times$ {w_12} + {x_2} $\\times$ {w_22} + {x_3} $\\times$ {w_32} + {b_2} = {y_2}'
))

# %%
x_1 = 100 # m^2
x_2 = 3 
x_3 = 2 
y = 500 # juta rupiah

w_11 = 0.1
w_21 = 0.2
w_31 = 0.3
b_1 = 0.0

w_12 = 0.4
w_22 = 0.5
w_32 = 0.6
b_2 = 0.0

y_1 = x_1 * w_11 + x_2 * w_21 + x_3 * w_31 + b_1
y_2 = x_1 * w_12 + x_2 * w_22 + x_3 * w_32 + b_2

display_output()
# Out:
# $y_1$ = 100 $\times$ 0.1 + 3 $\times$ 0.2 + 2 $\times$ 0.3 + 0.0 = 11.2
#
# $y_2$ = 100 $\times$ 0.4 + 3 $\times$ 0.5 + 2 $\times$ 0.6 + 0.0 = 42.7
