# %%
from IPython.display import display, Math, Latex

# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %%
def display_output():
    display(Latex(
    f"{' HIDDEN OUTPUT 1 '.center(40, '=')}\n\n"
	r'$y_{11}$' f'= {x_11} $\\times$ {w_11} + {x_12} $\\times$ {w_21} + {x_13} $\\times$ {w_31} + {b_1} = {y_1_neuron_1:.2f}\n\n'
	r'$y_{21}$' f'= {x_21} $\\times$ {w_11} + {x_22} $\\times$ {w_21} + {x_23} $\\times$ {w_31} + {b_1} = {y_2_neuron_1:.2f}\n\n'
	r'$y_{31}$' f'= {x_31} $\\times$ {w_11} + {x_32} $\\times$ {w_21} + {x_33} $\\times$ {w_31} + {b_1} = {y_3_neuron_1:.2f}\n\n'
	r'$y_{41}$' f'= {x_41} $\\times$ {w_11} + {x_42} $\\times$ {w_21} + {x_43} $\\times$ {w_31} + {b_1} = {y_4_neuron_1:.2f}\n\n'

    f"\{' HIDDEN OUTPUT 2 '.center(40, '=')}\n\n"
	r'$y_{12}$' f'= {x_11} $\\times$ {w_12} + {x_12} $\\times$ {w_22} + {x_13} $\\times$ {w_32} + {b_2} = {y_1_neuron_2:.2f}\n\n'
	r'$y_{22}$' f'= {x_21} $\\times$ {w_12} + {x_22} $\\times$ {w_22} + {x_23} $\\times$ {w_32} + {b_2} = {y_2_neuron_2:.2f}\n\n'
	r'$y_{32}$' f'= {x_31} $\\times$ {w_12} + {x_32} $\\times$ {w_22} + {x_33} $\\times$ {w_32} + {b_2} = {y_3_neuron_2:.2f}\n\n'
	r'$y_{42}$' f'= {x_41} $\\times$ {w_12} + {x_42} $\\times$ {w_22} + {x_43} $\\times$ {w_32} + {b_2} = {y_4_neuron_2:.2f}\n\n'
))

# %%
# LUAS TANAH m^2
x_11 = 100
x_21 = 150
x_31 = 175
x_41 = 200

# KAMAR TIDUR
x_12 = 3
x_22 = 5
x_32 = 5
x_42 = 6

# KAMAR MANDI
x_13 = 2
x_23 = 3
x_33 = 4
x_43 = 3

# HARGA RUMAH (juta rupiah)
y_1 = 500
y_2 = 850
y_3 = 900
y_4 = 1100

# WEIGHT PADA NEURON 1
w_11 = 0.1
w_21 = 0.2
w_31 = 0.3

# BIAS PADA NEURON 1
b_1 = 0.0

# WEIGHT PADA NEURON 2
w_12 = 0.4
w_22 = 0.5
w_32 = 0.6

# BIAS PADA NEURON 2
b_2 = 0.0

y_1_neuron_1 = x_11 * w_11 + x_12 * w_21 + x_13 * w_31 + b_1
y_2_neuron_1 = x_21 * w_11 + x_22 * w_21 + x_23 * w_31 + b_1
y_3_neuron_1 = x_31 * w_11 + x_32 * w_21 + x_33 * w_31 + b_1
y_4_neuron_1 = x_41 * w_11 + x_42 * w_21 + x_43 * w_31 + b_1

y_1_neuron_2 = x_11 * w_12 + x_12 * w_22 + x_13 * w_32 + b_2
y_2_neuron_2 = x_21 * w_12 + x_22 * w_22 + x_23 * w_32 + b_2
y_3_neuron_2 = x_31 * w_12 + x_32 * w_22 + x_33 * w_32 + b_2
y_4_neuron_2 = x_41 * w_12 + x_42 * w_22 + x_43 * w_32 + b_2


display_output()
# Out:
# =========== HIDDEN OUTPUT 1 ============
#
# $y_{11}$= 100 $\times$ 0.1 + 3 $\times$ 0.2 + 2 $\times$ 0.3 + 0.0 = 11.20
#
# $y_{21}$= 150 $\times$ 0.1 + 5 $\times$ 0.2 + 3 $\times$ 0.3 + 0.0 = 16.90
#
# $y_{31}$= 175 $\times$ 0.1 + 5 $\times$ 0.2 + 4 $\times$ 0.3 + 0.0 = 19.70
#
# $y_{41}$= 200 $\times$ 0.1 + 6 $\times$ 0.2 + 3 $\times$ 0.3 + 0.0 = 22.10
#
# \=========== HIDDEN OUTPUT 2 ============
#
# $y_{12}$= 100 $\times$ 0.4 + 3 $\times$ 0.5 + 2 $\times$ 0.6 + 0.0 = 42.70
#
# $y_{22}$= 150 $\times$ 0.4 + 5 $\times$ 0.5 + 3 $\times$ 0.6 + 0.0 = 64.30
#
# $y_{32}$= 175 $\times$ 0.4 + 5 $\times$ 0.5 + 4 $\times$ 0.6 + 0.0 = 74.90
#
# $y_{42}$= 200 $\times$ 0.4 + 6 $\times$ 0.5 + 3 $\times$ 0.6 + 0.0 = 84.80
